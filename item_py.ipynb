# %%
import pandas as pd
import statistics as st
df=pd.read_csv('item.csv') #reading the csv
df #displays the csv 
df['quantity'] #shows the quantity 
df.shape  #displays the shape of the matrix 
df['quantity'].mean()
df['quantity']=df['quantity'].fillna(df['quantity'].mean())

# %%
df
# Out:
#    id    item  quantity  price  bought  forenoon  afternoon
# 0   1    milk       2.0   67.0   672.0     456.0        NaN
# 1   2   sugar       1.0    NaN   453.0     234.0        NaN
# 2   3   chips       2.5   45.0   456.0     322.0        NaN
# 3   4  coffee       2.0   45.0   672.0     564.0        NaN
# 4   5    meat       4.0   56.0   786.0     221.0        NaN
# 5   6  chocos       3.0    NaN   345.0       NaN      213.0
# 6   7   juice       1.0   78.0   765.0       NaN      344.0
# 7   8     jam       2.5   65.0   665.0       NaN      333.0
# 8   9   bread       3.0    NaN     NaN       NaN      567.0
# 9  10  butter       4.0    NaN     NaN       NaN      322.0

# %%
df['price']=df['price'].fillna(df['price'].median())
df
# Out:
#    id    item  quantity  price  bought  forenoon  afternoon
# 0   1    milk       2.0   67.0   672.0     456.0        NaN
# 1   2   sugar       1.0   60.5   453.0     234.0        NaN
# 2   3   chips       2.5   45.0   456.0     322.0        NaN
# 3   4  coffee       2.0   45.0   672.0     564.0        NaN
# 4   5    meat       4.0   56.0   786.0     221.0        NaN
# 5   6  chocos       3.0   60.5   345.0       NaN      213.0
# 6   7   juice       1.0   78.0   765.0       NaN      344.0
# 7   8     jam       2.5   65.0   665.0       NaN      333.0
# 8   9   bread       3.0   60.5     NaN       NaN      567.0
# 9  10  butter       4.0   60.5     NaN       NaN      322.0

# %%
df['bought']=df['bought'].fillna(round(df['bought'].std(),2))
df
# Out:
#    id    item  quantity  price  bought  forenoon  afternoon
# 0   1    milk       2.0   67.0  672.00     456.0        NaN
# 1   2   sugar       1.0   60.5  453.00     234.0        NaN
# 2   3   chips       2.5   45.0  456.00     322.0        NaN
# 3   4  coffee       2.0   45.0  672.00     564.0        NaN
# 4   5    meat       4.0   56.0  786.00     221.0        NaN
# 5   6  chocos       3.0   60.5  345.00       NaN      213.0
# 6   7   juice       1.0   78.0  765.00       NaN      344.0
# 7   8     jam       2.5   65.0  665.00       NaN      333.0
# 8   9   bread       3.0   60.5  162.02       NaN      567.0
# 9  10  butter       4.0   60.5  162.02       NaN      322.0

# %%
df['forenoon']=df['forenoon'].fillna(df['forenoon'].mean())
df
# Out:
#    id    item  quantity  price  bought  forenoon  afternoon
# 0   1    milk       2.0   67.0  672.00     456.0        NaN
# 1   2   sugar       1.0   60.5  453.00     234.0        NaN
# 2   3   chips       2.5   45.0  456.00     322.0        NaN
# 3   4  coffee       2.0   45.0  672.00     564.0        NaN
# 4   5    meat       4.0   56.0  786.00     221.0        NaN
# 5   6  chocos       3.0   60.5  345.00     359.4      213.0
# 6   7   juice       1.0   78.0  765.00     359.4      344.0
# 7   8     jam       2.5   65.0  665.00     359.4      333.0
# 8   9   bread       3.0   60.5  162.02     359.4      567.0
# 9  10  butter       4.0   60.5  162.02     359.4      322.0

# %%
df['bought'].min()
# Out:
# 162.02
